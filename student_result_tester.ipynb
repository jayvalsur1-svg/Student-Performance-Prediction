# %%
import numpy as np

# %%
import pandas as pd

# %%
dataset=pd.read_csv('/content/student_study_results.csv')

# %%
dataset
# Out:
#     Hours_of_Study  Hours_of_Playing Result
# 0              5.2               0.7   Pass
# 1              3.7               2.7   Pass
# 2              5.6               2.8   Pass
# 3              7.8               1.9   Pass
# 4              3.4               3.2   Fail
# ..             ...               ...    ...
# 95             0.3               4.3   Fail
# 96             4.7               1.7   Pass
# 97             4.7               3.8   Pass
# 98             4.0               3.6   Fail
# 99             3.4               1.2   Fail
#
# [100 rows x 3 columns]

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Hours_of_Study    100 non-null    float64
#  1   Hours_of_Playing  100 non-null    float64
#  2   Result            100 non-null    object
# dtypes: float64(2), object(1)
# memory usage: 2.5+ KB

# %%
dataset.shape
# Out:
# (100, 3)

# %%
dataset.head()
# Out:
#    Hours_of_Study  Hours_of_Playing Result
# 0             5.2               0.7   Pass
# 1             3.7               2.7   Pass
# 2             5.6               2.8   Pass
# 3             7.8               1.9   Pass
# 4             3.4               3.2   Fail

# %%
data=dataset.iloc[:,:]
data['Result'] = data['Result'].map({'Pass': 1, 'Fail': 0})

# %%
data
# Out:
#     Hours_of_Study  Hours_of_Playing  Result
# 0              5.2               0.7       1
# 1              3.7               2.7       1
# 2              5.6               2.8       1
# 3              7.8               1.9       1
# 4              3.4               3.2       0
# ..             ...               ...     ...
# 95             0.3               4.3       0
# 96             4.7               1.7       1
# 97             4.7               3.8       1
# 98             4.0               3.6       0
# 99             3.4               1.2       0
#
# [100 rows x 3 columns]

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(data['Hours_of_Study'],data['Hours_of_Playing'],c=data['Result'])

# %%
x=data.iloc[:,0:2]

# %%
y=data.iloc[:,-1]

# %%
x
# Out:
#     Hours_of_Study  Hours_of_Playing
# 0              5.2               0.7
# 1              3.7               2.7
# 2              5.6               2.8
# 3              7.8               1.9
# 4              3.4               3.2
# ..             ...               ...
# 95             0.3               4.3
# 96             4.7               1.7
# 97             4.7               3.8
# 98             4.0               3.6
# 99             3.4               1.2
#
# [100 rows x 2 columns]

# %%
y
# Out:
# 0     1
# 1     1
# 2     1
# 3     1
# 4     0
#      ..
# 95    0
# 96    1
# 97    1
# 98    0
# 99    0
# Name: Result, Length: 100, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.1)

# %%
x_train
# Out:
#     Hours_of_Study  Hours_of_Playing
# 30             2.5               0.4
# 3              7.8               1.9
# 15             2.6               4.1
# 78             4.2               3.0
# 90             4.2               2.6
# ..             ...               ...
# 17             4.8               1.2
# 1              3.7               2.7
# 93             3.2               1.0
# 41             4.4               6.1
# 98             4.0               3.6
#
# [90 rows x 2 columns]

# %%
x_test
# Out:
#     Hours_of_Study  Hours_of_Playing
# 91             6.4               5.2
# 52             2.3               2.1
# 45             2.2               5.1
# 19             0.5               5.0
# 75             6.1               5.2
# 57             3.2               4.4
# 71             7.8               1.9
# 95             0.3               4.3
# 88             2.7               1.8
# 32             4.0               1.4

# %%
y_train
# Out:
# 30    0
# 3     1
# 15    0
# 78    1
# 90    1
#      ..
# 17    1
# 1     1
# 93    1
# 41    1
# 98    0
# Name: Result, Length: 90, dtype: int64

# %%
y_test
# Out:
# 91    1
# 52    0
# 45    0
# 19    0
# 75    1
# 57    0
# 71    1
# 95    0
# 88    0
# 32    0
# Name: Result, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %%
x_train=scaler.fit_transform(x_train)

# %%
x_train
# Out:
# array([[-0.62679764, -1.65873409],
#        [ 1.89201005, -0.86240016],
#        [-0.57927296,  0.30555628],
#        [ 0.18112181, -0.27842194],
#        [ 0.18112181, -0.49077765],
#        [-1.62481578, -1.4994673 ],
#        [ 0.70389322, -1.60564516],
#        [ 0.51379452, -0.91548908],
#        [ 1.03656593,  0.99571236],
#        [-1.10204437, -0.06606622],
#        [-0.53174829,  0.517912  ],
#        [ 1.17913995,  0.46482307],
#        [-1.14956904,  0.46482307],
#        [-0.48422362, -1.02166694],
#        [-0.48422362, -0.06606622],
#        [ 0.46626985,  0.25246735],
#        [ 0.51379452,  0.517912  ],
#        [-0.1515509 ,  0.67717878],
#        [ 1.93953473,  0.35864521],
#        [ 1.70191136,  0.41173414],
#        [ 0.94151658,  0.25246735],
#        [-0.864421  , -0.22533301],
#        [-1.81491447,  2.37602451],
#        [-0.76937166,  0.19937842],
#        [-1.48224176,  0.83644557],
#        [ 1.0840906 , -0.96857801],
#        [ 0.32369583, -1.34020052],
# ...

# %%
x_test=scaler.transform(x_test)

# %%
x_test
# Out:
# array([[ 1.22666463,  0.8895345 ],
#        [-0.72184698, -0.7562223 ],
#        [-0.76937166,  0.83644557],
#        [-1.5772911 ,  0.78335664],
#        [ 1.0840906 ,  0.8895345 ],
#        [-0.29412492,  0.46482307],
#        [ 1.89201005, -0.86240016],
#        [-1.67234045,  0.41173414],
#        [-0.53174829, -0.91548908],
#        [ 0.08607246, -1.1278448 ]])

# %%
from sklearn.linear_model import LogisticRegression

# %%
frm=LogisticRegression()

# %%
frm.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
acc=frm.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,acc)
# Out:
# 0.9

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(x_train,y_train.values,clf=frm,legend=2)
# Out:
# <Axes: >

# %%
import pickle

# %%
pickle.dump(frm,open('model.pkl','wb'))
